# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Sabri\\OneDrive\\Masaüstü\\targets\\targets.simple.csv")

# %%
df.sample(10)
# Out:
#                                                      id  schema  \
# 648                           NK-ZabMFpoqopbPN4uquVoFPY  Person
# 1075  tr-wanted-0e59f504e3557392ae67becf75be0fb61417...  Person
# 1715  tr-wanted-793c3045fbd46ea6f55e4c00e5add7f8a2cd...  Person
# 2356  tr-wanted-df98818b3077f3dba8d4e334e21e610fc24f...  Person
# 879                           NK-m9UPtmk9TcV3kmKoyRLFp2  Person
# 2101  tr-wanted-b35fe15aeef5fdeb8583dc8ec5b6e65cdb3a...  Person
# 1548  tr-wanted-5d871325a6dc0d0367a32426d16be5f6760f...  Person
# 580                           NK-WSze6kVuvPSy8PWRf6shP2  Person
# 712                           NK-cknNK5GtWcvReQYmouAtKX  Person
# 2179  tr-wanted-c011fb302db31473ad64b9757d44f6e3b2fb...  Person
#
#                            name  aliases  birth_date countries  addresses  \
# 648                Hikmet ÇOBAN      NaN      1964.0        tr        NaN
# 1075               Tuğba TOPRAK      NaN      1982.0        tr        NaN
# ...
